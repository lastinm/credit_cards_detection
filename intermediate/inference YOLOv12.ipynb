# %%
from ultralytics import YOLO
import cv2
import supervision as sv
import torch

# %%
# !nvidia-smi
# Out:
# Fri May  2 12:32:53 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.133.20             Driver Version: 570.133.20     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070        Off |   00000000:01:00.0  On |                  N/A |
# |  0%   40C    P8             18W /  200W |    1770MiB /  12282MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            1944      G   /usr/lib/xorg/Xorg                      257MiB |
# |    0   N/A  N/A            2573      G   /usr/bin/ksmserver                        3MiB |
# |    0   N/A  N/A            2575      G   /usr/bin/kded5                            3MiB |
# |    0   N/A  N/A            2576      G   /usr/bin/kwin_x11                        62MiB |
# |    0   N/A  N/A            2602      G   /usr/bin/plasmashell                     27MiB |
# |    0   N/A  N/A            2647      G   ...it-kde-authentication-agent-1          3MiB |
# |    0   N/A  N/A            2649      G   ...ibexec/xdg-desktop-portal-kde          3MiB |
# |    0   N/A  N/A            2799      G   ...linux-gnu/libexec/kdeconnectd          3MiB |
# |    0   N/A  N/A            2829      G   /usr/bin/kaccess                          3MiB |
# |    0   N/A  N/A            2835      G   ...-gnu/libexec/DiscoverNotifier          3MiB |
# |    0   N/A  N/A            2884      G   ...6597/usr/bin/telegram-desktop          2MiB |
# |    0   N/A  N/A            2980      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3040      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3109      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3157      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3199      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3264      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3398      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3516      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3575      G   /usr/lib/zotero/zotero-bin               22MiB |
# |    0   N/A  N/A            3623      G   /usr/bin/doublecmd                        3MiB |
# |    0   N/A  N/A            3728      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A            3801      G   /usr/bin/okular                           3MiB |
# |    0   N/A  N/A            4084      G   ...ess --variations-seed-version        325MiB |
# |    0   N/A  N/A            4242      G   /usr/bin/kwalletd5                        3MiB |
# |    0   N/A  N/A            5290      C   ...ds_detection/.venv/bin/python        562MiB |
# |    0   N/A  N/A           13675      G   /opt/google/chrome/chrome                 3MiB |
# |    0   N/A  N/A           13748      G   ...ersion=20250501-180230.762000         47MiB |
# |    0   N/A  N/A           14009      G   ...asma-browser-integration-host          3MiB |
# |    0   N/A  N/A           31498      G   ...nux-gnu/libexec/kf5/kioslave5          2MiB |
# |    0   N/A  N/A           32130      G   /usr/bin/dolphin                          3MiB |
# |    0   N/A  N/A           35854      G   ...nux-gnu/libexec/kf5/kioslave5          2MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (8.3.63)
# Requirement already satisfied: numpy>=1.23.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (2.2.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (1.15.1)
# Requirement already satisfied: torch>=1.8.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (2.6.0)
# Requirement already satisfied: torchvision>=0.9.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (0.21.0)
# Requirement already satisfied: tqdm>=4.64.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.5)
# Requirement already satisfied: fsspec in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: setuptools in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/lastinm/PROJECTS/CV/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %% [markdown]
# ## Run inference

# %%
image_path1 = '/home/lastinm/PROJECTS/credit_cards_detection/dataset/coco/test/1742460932042_resized_jpg.rf.cc580bf6003a8859a97b0c846b08415c.jpg'
image_path2 = '/home/lastinm/PROJECTS/credit_cards_detection/dataset/coco/test/1742460932095_resized_jpg.rf.8db93580eb26ebfc3f87db415cf4f1df.jpg'

# %%
def prepare_image(image_path):
    model = YOLO(f'/home/lastinm/PROJECTS/credit_cards_detection/train/YOLOv12/runs/detect/train3/weights/best.pt')
    image = cv2.imread(image_path)

    results = model(image, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results).with_nms()

    box_annotator = sv.BoxAnnotator()
    label_annotator = sv.LabelAnnotator()

    annotated_image = image.copy()
    annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    sv.plot_image(annotated_image)

# %%
prepare_image(image_path1)
prepare_image(image_path2)

# %% [markdown]
# # ОТОБРАЗИТЬ РЕЗУЛЬТАТ ЧЕРЕЗ MATHPLOTLIB

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
def visualize_results_matplotlib(image_path, results, class_names):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    fig, ax = plt.subplots(1, figsize=(12, 8))
    ax.imshow(image)
    
    #colors = ['yellow', 'green', 'blue', 'red', 'purple']
    colors = ['green', 'blue', 'red', 'purple']
    
    for box, score, cls in zip(results['boxes'], results['scores'], results['classes']):
        x1, y1, x2, y2 = map(int, box)
        rect = patches.Rectangle(
            (x1, y1), x2-x1, y2-y1,
            linewidth=2, edgecolor=colors[cls % len(colors)], facecolor='none'
        )
        ax.add_patch(rect)
        
        plt.text(
            x1, y1-10, f"{class_names[cls]}: {score:.2f}",
            color=colors[cls % len(colors)], fontsize=10,
            bbox=dict(facecolor='white', alpha=0.8)
        )
    
    plt.axis('off')
    plt.show()

# %%
def process_image(image_path):
    # 1. Детекция на изображении
    model = YOLO(f'/home/lastinm/PROJECTS/credit_cards_detection/train/YOLOv12/runs/detect/train3/weights/best.pt')
    image = cv2.imread(image_path)

    results = model(image, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results).with_nms()

    # 2. Визуализация
    #class_names = ["Background", "Cardholder", "CardNumber", "DateExpired"]  # Faster R-CNN
    class_names = ["Cardholder", "CardNumber", "DateExpired"]

    # Собираем результаты в словарь, как в Faster R-CNN
    results = {
        'boxes': torch.tensor(detections.xyxy),  # [N, 4] (x1, y1, x2, y2)
        'scores': torch.tensor(detections.confidence),  # [N]
        'classes': torch.tensor(detections.class_id, dtype=torch.int64),  # [N]
    }

    visualize_results_matplotlib(image_path, results, class_names)

# %%
process_image(image_path1)
process_image(image_path2)
